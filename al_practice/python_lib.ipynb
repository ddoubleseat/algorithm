# %% [markdown]
# # 잊어버리기 쉬운 파이썬 라이브러리 정리

# %% [markdown]
# ### import time

# %% [markdown]
# * Program 수행 시간 확인

# %%
from time import time
N = 50000000
d = []

a = range(N)
startTime = time()

for i in a:
    d.append(2*i)
    
endTime = time()
print(endTime - startTime)
# Out:
# 6.108000040054321
